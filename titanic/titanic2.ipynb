# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('train.csv')
df=pd.DataFrame(train)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=df.drop(['PassengerId','Cabin'],axis=1)

# %%
np.sum(df.isnull())
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df=df.drop(['Name',"Ticket",'Age'],axis=1)

# %%
df[25:56]
# Out:
#     Survived  Pclass     Sex  SibSp  Parch      Fare Embarked
# 25         1       3  female      1      5   31.3875        S
# 26         0       3    male      0      0    7.2250        C
# 27         0       1    male      3      2  263.0000        S
# 28         1       3  female      0      0    7.8792        Q
# 29         0       3    male      0      0    7.8958        S
# 30         0       1    male      0      0   27.7208        C
# 31         1       1  female      1      0  146.5208        C
# 32         1       3  female      0      0    7.7500        Q
# 33         0       2    male      0      0   10.5000        S
# 34         0       1    male      1      0   82.1708        C
# 35         0       1    male      1      0   52.0000        S
# 36         1       3    male      0      0    7.2292        C
# 37         0       3    male      0      0    8.0500        S
# 38         0       3  female      2      0   18.0000        S
# ...

# %%
import random as rn

# %%
rn.choices(['Q','C','S'])
# Out:
# ['S']

# %%
np.where(df['Embarked'].isnull() == True)[0]
# Out:
# array([829], dtype=int64)

# %%
df['Embarked'][61]=rn.choices(['Q','C','S'])[0]
df['Embarked'][829]=rn.choices(['Q','C','S'])[0]
# Out:
# C:\Users\Sparsh\AppData\Local\Temp\ipykernel_22956\2299107260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Embarked'][61]=rn.choices(['Q','C','S'])[0]
# C:\Users\Sparsh\AppData\Local\Temp\ipykernel_22956\2299107260.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Embarked'][829]=rn.choices(['Q','C','S'])[0]

# %%
df=pd.get_dummies(df)

# %%
y_train=df['Survived']

# %%
df
# Out:
#      Survived  Pclass  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3      1      0   7.2500           0         1
# 1           1       1      1      0  71.2833           1         0
# 2           1       3      0      0   7.9250           1         0
# 3           1       1      1      0  53.1000           1         0
# 4           0       3      0      0   8.0500           0         1
# ..        ...     ...    ...    ...      ...         ...       ...
# 886         0       2      0      0  13.0000           0         1
# 887         1       1      0      0  30.0000           1         0
# 888         0       3      1      2  23.4500           1         0
# 889         1       1      0      0  30.0000           0         1
# 890         0       3      0      0   7.7500           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# ...

# %%
df=df.drop('Survived',axis=1)

# %%
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split

# %%
X=scale(df)

# %%
log=LogisticRegression()
log.fit(X,y_train)
# Out:
# LogisticRegression()

# %%
ypred=log.predict(X)
from sklearn.metrics import classification_report
print(classification_report(y_train,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       549
#            1       0.76      0.69      0.72       342
#
#     accuracy                           0.80       891
#    macro avg       0.79      0.78      0.78       891
# weighted avg       0.79      0.80      0.79       891

# %%
test=pd.read_csv('test.csv')
dft=pd.DataFrame(test)

# %%
dft=dft.drop(['PassengerId','Cabin','Name',"Ticket",'Age'],axis=1)

# %%
dft
# Out:
#      Pclass     Sex  SibSp  Parch      Fare Embarked
# 0         3    male      0      0    7.8292        Q
# 1         3  female      1      0    7.0000        S
# 2         2    male      0      0    9.6875        Q
# 3         3    male      0      0    8.6625        S
# 4         3  female      1      1   12.2875        S
# ..      ...     ...    ...    ...       ...      ...
# 413       3    male      0      0    8.0500        S
# 414       1  female      0      0  108.9000        C
# 415       3    male      0      0    7.2500        S
# 416       3    male      0      0    8.0500        S
# 417       3    male      1      1   22.3583        C
#
# [418 rows x 6 columns]

# %%
np.sum(dft.isnull())
# Out:
# Pclass      0
# Sex         0
# SibSp       0
# Parch       0
# Fare        1
# Embarked    0
# dtype: int64

# %%
temp=np.where(dft['Fare'].isnull()==True)[0]
temp
# Out:
# array([152], dtype=int64)

# %%
dft['Fare'][temp]=np.mean(dft['Fare'])
# Out:
# C:\Users\Sparsh\AppData\Local\Temp\ipykernel_22956\679390826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['Fare'][temp]=np.mean(dft['Fare'])

# %%
np.sum(dft.isnull())
# Out:
# Pclass      0
# Sex         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
dft=pd.get_dummies(dft)

# %%
X_test=scale(dft)

# %%
y2=log.predict(X_test)

# %%
new=pd.read_csv('test.csv')
new=pd.DataFrame(new)
y2=pd.DataFrame(y2)

# %%
import openpyxl as xl

# %%
neww=pd.concat([new['PassengerId'],y2],axis=1)

# %%
neww
# Out:
#      PassengerId  0
# 0            892  0
# 1            893  1
# 2            894  0
# 3            895  0
# 4            896  1
# ..           ... ..
# 413         1305  0
# 414         1306  1
# 415         1307  0
# 416         1308  0
# 417         1309  0
#
# [418 rows x 2 columns]

# %%
neww.to_excel('results.xlsx',sheet_name='new_sheet_name')
